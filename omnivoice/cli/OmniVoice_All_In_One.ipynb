# %% [markdown]
# # OmniVoice Custom Fork (All-in-One)
#
# This notebook installs your custom fork of OmniVoice and launches the interactive Gradio demo with your updated default settings.
#
# **Instructions:**
# Just click the **Play** button on the cell below. It will install the dependencies and then provide you with a public Gradio `gradio.live` link.

# %%
# 1. Install system dependencies
# !apt-get update && apt-get install -y espeak-ng libespeak-ng-dev ffmpeg

# 2. Download and Patch aeneas for Python 3.12 compatibility
# !wget https://github.com/readbeyond/aeneas/archive/refs/tags/v1.7.3.tar.gz
# !tar -xzf v1.7.3.tar.gz
# This command removes the high-performance C-extensions requirement which causes the crash
# !sed -i 's/extensions=\[ext_cew\]/extensions=\[\]/g' aeneas-1.7.3/setup.py
# !pip install ./aeneas-1.7.3

# 3. Install your custom OmniVoice fork
# !pip install git+https://github.com/nohuggy/OmniVoice.git

# 4. Install other requirements
# !pip install soundfile numpy beautifulsoup4 lxml

# 5. Launch the Gradio WebUI
# !omnivoice-demo --share
