# %% [markdown]
# # OmniVoice Custom Fork (All-in-One)
#
# This notebook installs your custom fork of OmniVoice and launches the interactive Gradio demo with your updated default settings.
#
# **Instructions:**
# Just click the **Play** button on the cell below. It will install the dependencies and then provide you with a public Gradio `gradio.live` link.

# %%
# 1. Install system dependencies
# !apt-get update && apt-get install -y espeak-ng ffmpeg

# 2. RADICAL FIX: Manual aeneas deployment (Bypasses all pip/setup errors)
print("Deploying aeneas manually...")
# !wget -q https://github.com/readbeyond/aeneas/archive/refs/tags/v1.7.3.tar.gz
# !tar -xzf v1.7.3.tar.gz
# We move the core aeneas folder into the current directory so it's importable
# !cp -r aeneas-1.7.3/aeneas .
# Install its only missing Python dependencies
# !pip install -q beautifulsoup4 lxml

# 3. Install OmniVoice and dependencies
# !pip install -q git+https://github.com/nohuggy/OmniVoice.git
# !pip install -q soundfile numpy

# 4. Set Environment Variable to use Python-only mode
import os
os.environ["PYTHON_ONLY"] = "1"

# 5. Launch the Gradio WebUI
# !omnivoice-demo --share
